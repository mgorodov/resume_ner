# %%
from pathlib import Path
from kaggle.api.kaggle_api_extended import KaggleApi

DATASET_DIR = Path.cwd() / "datasets" / "dataturks"
DATASET_PATH = DATASET_DIR / "Entity Recognition in Resumes.json"

if DATASET_DIR.exists():
    print("Dataset already loaded")
else:
    api = KaggleApi()
    api.authenticate()
    api.dataset_download_files('dataturks/resume-entities-for-ner', path=DATASET_DIR, quiet=False, unzip=True)
# Out:
# Dataset already loaded

# %%
import spacy
import json
import re

  
def convert_dataturks_to_spacy(dataturks_JSON_FilePath):
    nlp = spacy.blank("en")
    training_data = []
    
    with open(dataturks_JSON_FilePath, 'r', encoding='utf-8') as f:
        lines = f.readlines()
    
    for line in lines:
        data = json.loads(line)
        text = data['content'].replace("\n", " ").replace("\t", " ").strip()
        doc = nlp.make_doc(text)
        
        entities = []
        data_annotations = data['annotation']
        
        if data_annotations is not None:
            for annotation in data_annotations:
                point = annotation['points'][0]
                labels = annotation['label']
                if not isinstance(labels, list):
                    labels = [labels]
                
                for label in labels:
                    point_start = point['start']
                    point_end = point['end']
                    point_text = point['text'].strip()
                    
                    if not point_text:
                        continue
                    
                    matches = list(re.finditer(re.escape(point_text), text))
                    if matches:
                        match_start, match_end = matches[0].span()
                        
                        token_starts = [token.idx for token in doc]
                        token_ends = [token.idx + len(token.text) for token in doc]
                        
                        if match_start in token_starts and match_end in token_ends:
                            entities.append((match_start, match_end, label))
                        else:
                            containing_tokens = []
                            for token in doc:
                                if token.idx <= match_start < token.idx + len(token.text):
                                    containing_tokens.append(token)
                                elif token.idx < match_end <= token.idx + len(token.text):
                                    containing_tokens.append(token)
                            
                            if containing_tokens:
                                start_token = containing_tokens[0]
                                end_token = containing_tokens[-1]
                                entities.append((
                                    start_token.idx,
                                    end_token.idx + len(end_token.text),
                                    label
                                ))
        
        training_data.append((text, {"entities": entities}))
    
    return training_data

def trim_entity_spans(data: list) -> list:
    invalid_span_tokens = re.compile(r'\s')

    cleaned_data = []
    for text, annotations in data:
        entities = annotations['entities']
        valid_entities = []
        for start, end, label in entities:
            valid_start = start
            valid_end = end
            while valid_start < len(text) and invalid_span_tokens.match(
                    text[valid_start]):
                valid_start += 1
            while valid_end > 1 and invalid_span_tokens.match(
                    text[valid_end - 1]):
                valid_end -= 1
            valid_entities.append([valid_start, valid_end, label])
        cleaned_data.append([text, {'entities': valid_entities}])
    return cleaned_data

# %%
data = trim_entity_spans(convert_dataturks_to_spacy(DATASET_PATH))
data[0]
# Out:
# ["Abhishek Jha Application Development Associate - Accenture  Bengaluru, Karnataka - Email me on Indeed: indeed.com/r/Abhishek-Jha/10e7a8cb732bc43a  • To work for an organization which provides me the opportunity to improve my skills and knowledge for my individual and company's growth in best possible ways.  Willing to relocate to: Bangalore, Karnataka  WORK EXPERIENCE  Application Development Associate  Accenture -  November 2017 to Present  Role: Currently working on Chat-bot. Developing Backend Oracle PeopleSoft Queries for the Bot which will be triggered based on given input. Also, Training the bot for different possible utterances (Both positive and negative), which will be given as input by the user.  EDUCATION  B.E in Information science and engineering  B.v.b college of engineering and technology -  Hubli, Karnataka  August 2013 to June 2017  12th in Mathematics  Woodbine modern school  April 2011 to March 2013  10th  Kendriya Vidyalaya  April 2001 to March 2011  SKILLS  C (Less than 1 year), Database (Less than 1 year), Database Management (Less than 1 year), Database Management System (Less than 1 year), Java (Less than 1 year)  ADDITIONAL INFORMATION  Technical Skills  https://www.indeed.com/r/Abhishek-Jha/10e7a8cb732bc43a?isid=rex-download&ikw=download-top&co=IN   • Programming language: C, C++, Java • Oracle PeopleSoft • Internet Of Things • Machine Learning • Database Management System • Computer Networks • Operating System worked on: Linux, Windows, Mac  Non - Technical Skills  • Honest and Hard-Working • Tolerant and Flexible to Different Situations • Polite and Calm • Team-Player",
#  {'entities': [[939, 957, 'College Name'],
#    [883, 905, 'College Name'],
#    [429, 433, 'Graduation Year'],
#    [771, 814, 'College Name'],
#    [727, 769, 'Designation'],
#    [49, 58, 'Companies worked at'],
#    [13, 46, 'Designation'],
#    [95, 145, 'Email Address'],
#    [60, 69, 'Location'],
#    [49, 58, 'Companies worked at'],
#    [13, 46, 'Designation'],
#    [0, 12, 'Name']]}]

# %%
import random
import math

def train_test_split(data, test_size, random_state):

    random.Random(random_state).shuffle(data)
    test_idx = len(data) - math.floor(test_size * len(data))
    train_set = data[0: test_idx]
    test_set = data[test_idx: ]

    return train_set, test_set

# %%
train_data, test_data = train_test_split(data, test_size = 0.1, random_state = 42)

# %%
def filter_overlapping_entities(data):
    """Remove overlapping entities from training data"""
    cleaned_data = []
    
    for text, annotations in data:
        entities = annotations.get("entities", [])
        
        if not entities:
            cleaned_data.append((text, annotations))
            continue
        
        entities.sort(key=lambda x: x[0])
        
        non_overlapping = []
        prev_end = -1
        
        for start, end, label in entities:
            if start < prev_end:
                print(f"Warning: Skipping overlapping entity '{text[start:end]}' ({label})")
                continue
            
            non_overlapping.append((start, end, label))
            prev_end = end
        
        cleaned_data.append((text, {"entities": non_overlapping}))
    
    return cleaned_data

# %%
train_data = filter_overlapping_entities(train_data)
test_data = filter_overlapping_entities(test_data)
# Out:
# Warning: Skipping overlapping entity 'System Engineer' (Designation)
# Warning: Skipping overlapping entity 'System Engineer' (Designation)
# Warning: Skipping overlapping entity 'Infosys Limited' (Companies worked at)
# Warning: Skipping overlapping entity 'Infosys Limited' (Companies worked at)
# Warning: Skipping overlapping entity 'Bangalore' (Location)
# Warning: Skipping overlapping entity 'Hyderabad' (Location)
# Warning: Skipping overlapping entity 'Hyderabad' (Location)
# Warning: Skipping overlapping entity 'Hyderabad' (Location)
# Warning: Skipping overlapping entity 'indeed.com/r/Koushik-Katta/a6b19244854199ec' (Email Address)
# Warning: Skipping overlapping entity 'Infosys limited' (Companies worked at)
# Warning: Skipping overlapping entity '2014' (Graduation Year)
# Warning: Skipping overlapping entity '2014' (Graduation Year)
# Warning: Skipping overlapping entity '2014' (Graduation Year)
# Warning: Skipping overlapping entity '2010' (Graduation Year)
# Warning: Skipping overlapping entity 'Engineer / Electrical Supervisor,' (Designation)
# Warning: Skipping overlapping entity 'Engineer / Electrical Supervisor,' (Designation)
# Warning: Skipping overlapping entity 'Hyderabad' (Location)
# Warning: Skipping overlapping entity 'Hyderabad' (Location)
# Warning: Skipping overlapping entity 'Senior Systems Engineer' (Designation)
# Warning: Skipping overlapping entity 'Infosys Limited' (Companies worked at)
# Warning: Skipping overlapping entity 'Mainframe' (Skills)
# Warning: Skipping overlapping entity 'Mainframe' (Skills)
# Warning: Skipping overlapping entity 'Teradata' (Skills)
# Warning: Skipping overlapping entity 'Teradata' (Skills)
# Warning: Skipping overlapping entity 'Server Support Engineer' (Designation)
# Warning: Skipping overlapping entity 'Gurgaon' (Location)
# Warning: Skipping overlapping entity 'indeed.com/r/Mohini-Gupta/08b5b8e1acd8cf07' (Email Address)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'HR Executive' (Designation)
# Warning: Skipping overlapping entity 'HR Executive' (Designation)
# Warning: Skipping overlapping entity '2016' (Graduation Year)
# Warning: Skipping overlapping entity '2016' (Graduation Year)
# Warning: Skipping overlapping entity '2016' (Graduation Year)
# Warning: Skipping overlapping entity '2016' (Graduation Year)
# Warning: Skipping overlapping entity 'MBA' (Degree)
# Warning: Skipping overlapping entity 'Maximo Consultant' (Designation)
# Warning: Skipping overlapping entity 'Maximo Consultant' (Designation)
# Warning: Skipping overlapping entity 'Maximo Consultant' (Designation)
# Warning: Skipping overlapping entity 'Maximo Consultant' (Designation)
# Warning: Skipping overlapping entity 'Infosys Limited' (Companies worked at)
# Warning: Skipping overlapping entity 'Infosys Limited' (Companies worked at)
# Warning: Skipping overlapping entity 'Infosys Limited' (Companies worked at)
# Warning: Skipping overlapping entity 'Namakkal' (Location)
# Warning: Skipping overlapping entity 'indeed.com/r/Yathishwaran-P/a9c8d42210af40b8' (Email Address)
# Warning: Skipping overlapping entity 'Cuddapah' (Location)
# Warning: Skipping overlapping entity 'Cuddapah' (Location)
# Warning: Skipping overlapping entity 'Cuddapah' (Location)
# Warning: Skipping overlapping entity 'ms office' (Skills)
# Warning: Skipping overlapping entity 'LEAD ENGINEER' (Designation)
# Warning: Skipping overlapping entity 'CISCO' (Companies worked at)
# Warning: Skipping overlapping entity 'indeed.com/r/Pradeeba-V/19ff20f4b8552375' (Email Address)
# Warning: Skipping overlapping entity 'JAVASCRIPT' (Skills)
# Warning: Skipping overlapping entity 'JAVASCRIPT' (Skills)
# Warning: Skipping overlapping entity 'OOJS' (Skills)
# Warning: Skipping overlapping entity 'HTML5' (Skills)
# Warning: Skipping overlapping entity 'HTML5' (Skills)
# Warning: Skipping overlapping entity 'HTML5' (Skills)
# Warning: Skipping overlapping entity 'HTML5' (Skills)
# Warning: Skipping overlapping entity 'HTML5' (Skills)
# Warning: Skipping overlapping entity 'HTML5' (Skills)
# Warning: Skipping overlapping entity 'CSS3' (Skills)
# Warning: Skipping overlapping entity 'CSS3' (Skills)
# Warning: Skipping overlapping entity 'CSS3' (Skills)
# Warning: Skipping overlapping entity 'CSS3' (Skills)
# Warning: Skipping overlapping entity 'REST' (Skills)
# Warning: Skipping overlapping entity 'REST' (Skills)
# Warning: Skipping overlapping entity 'DOJO' (Skills)
# Warning: Skipping overlapping entity 'DOJO' (Skills)
# Warning: Skipping overlapping entity 'DOJO' (Skills)
# Warning: Skipping overlapping entity 'DOJO' (Skills)
# Warning: Skipping overlapping entity 'Angular JS' (Skills)
# Warning: Skipping overlapping entity 'SVN' (Skills)
# Warning: Skipping overlapping entity 'Code Collaborator' (Skills)
# Warning: Skipping overlapping entity 'SYSTEMS ENGINEER' (Designation)
# Warning: Skipping overlapping entity 'SYSTEMS ENGINEER' (Designation)
# Warning: Skipping overlapping entity 'indeed.com/r/Sharan-Adla/3a382a7b7296a764' (Email Address)
# Warning: Skipping overlapping entity 'TCS Security guard' (Designation)
# Warning: Skipping overlapping entity 'indeed.com/r/Keshav-Dhawale/f5ce584c13e7368d' (Email Address)
# Warning: Skipping overlapping entity 'Faridabad' (Location)
# Warning: Skipping overlapping entity 'indeed.com/r/amarjyot-sodhi/ba2e5a3cbaeccdac' (Email Address)
# Warning: Skipping overlapping entity 'Technical Project Manager' (Designation)
# Warning: Skipping overlapping entity 'Hyderabad' (Location)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Bhubaneshwar,' (Location)
# Warning: Skipping overlapping entity 'Senior Associate Consultant' (Designation)
# Warning: Skipping overlapping entity 'Senior Associate Consultant' (Designation)
# Warning: Skipping overlapping entity 'Associate Consultant' (Designation)
# Warning: Skipping overlapping entity 'Associate Consultant' (Designation)
# Warning: Skipping overlapping entity 'indeed.com/r/Ayushi-Srivastava/2bf1c4b058984738' (Email Address)
# Warning: Skipping overlapping entity '2016' (Graduation Year)
# Warning: Skipping overlapping entity '2012' (Graduation Year)
# Warning: Skipping overlapping entity 'Bengaluru' (Location)
# Warning: Skipping overlapping entity 'Accenture' (Companies worked at)
# Warning: Skipping overlapping entity '2013' (Graduation Year)
# Warning: Skipping overlapping entity 'Technology Analyst' (Designation)
# Warning: Skipping overlapping entity 'Technology Analyst' (Designation)
# Warning: Skipping overlapping entity 'Chennai' (Location)
# Warning: Skipping overlapping entity 'Chennai' (Location)
# Warning: Skipping overlapping entity 'Chennai' (Location)
# Warning: Skipping overlapping entity 'Chennai' (Location)
# Warning: Skipping overlapping entity 'Chennai' (Location)
# Warning: Skipping overlapping entity 'indeed.com/r/Dhanushkodi-Raj/cf31bbac6c5a5d29' (Email Address)
# Warning: Skipping overlapping entity 'Win2008' (Graduation Year)
# Warning: Skipping overlapping entity 'Win2008' (Graduation Year)
# Warning: Skipping overlapping entity 'Infosys Ltd/Edgeverve Systems Ltd' (Companies worked at)
# Warning: Skipping overlapping entity 'Bengaluru' (Location)
# Warning: Skipping overlapping entity 'Bengaluru' (Location)
# Warning: Skipping overlapping entity 'indeed.com/r/Mayank-Shukla/3c6042bd141ad353' (Email Address)
# Warning: Skipping overlapping entity 'Security Analyst' (Designation)
# Warning: Skipping overlapping entity 'Architect' (Designation)
# Warning: Skipping overlapping entity 'Architect' (Designation)
# Warning: Skipping overlapping entity 'Microsoft India' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft India' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft India' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft India' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft India' (Companies worked at)
# Warning: Skipping overlapping entity 'Hyderabad' (Location)
# Warning: Skipping overlapping entity 'Hyderabad' (Location)
# Warning: Skipping overlapping entity 'Hyderabad' (Location)
# Warning: Skipping overlapping entity 'Hyderabad' (Location)
# Warning: Skipping overlapping entity '2018' (Graduation Year)
# Warning: Skipping overlapping entity 'Microsoft Dainamic Software Billing Operator' (Designation)
# Warning: Skipping overlapping entity 'Test Analyst' (Designation)
# Warning: Skipping overlapping entity 'Test Analyst' (Designation)
# Warning: Skipping overlapping entity 'Oracle' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle' (Companies worked at)
# Warning: Skipping overlapping entity 'Hyderabad' (Location)
# Warning: Skipping overlapping entity 'Hyderabad' (Location)
# Warning: Skipping overlapping entity 'Hyderabad' (Location)
# Warning: Skipping overlapping entity 'Hyderabad' (Location)
# Warning: Skipping overlapping entity 'Hyderabad' (Location)
# Warning: Skipping overlapping entity 'Hyderabad' (Location)
# Warning: Skipping overlapping entity 'QA Analyst' (Designation)
# Warning: Skipping overlapping entity 'Osmania University' (College Name)
# Warning: Skipping overlapping entity 'Microsoft Partner Readiness Operations Project Manager (APAC)' (Designation)
# Warning: Skipping overlapping entity 'Microsoft GPS' (Companies worked at)
# Warning: Skipping overlapping entity 'Bangalore' (Location)
# Warning: Skipping overlapping entity 'Bangalore' (Location)
# Warning: Skipping overlapping entity 'Bangalore' (Location)
# Warning: Skipping overlapping entity 'Bangalore' (Location)
# Warning: Skipping overlapping entity 'Bangalore' (Location)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity '2013' (Graduation Year)
# Warning: Skipping overlapping entity 'Systems Engineer' (Designation)
# Warning: Skipping overlapping entity 'Systems Engineer' (Designation)
# Warning: Skipping overlapping entity 'Infosys Ltd' (Companies worked at)
# Warning: Skipping overlapping entity 'Delhi' (Location)
# Warning: Skipping overlapping entity 'Delhi' (Location)
# Warning: Skipping overlapping entity 'Delhi' (Location)
# Warning: Skipping overlapping entity 'Delhi' (Location)
# Warning: Skipping overlapping entity 'SAP Security' (Skills)
# Warning: Skipping overlapping entity 'SAP Security' (Skills)
# Warning: Skipping overlapping entity '2015' (Graduation Year)
# Warning: Skipping overlapping entity 'CBSE' (Degree)
# Warning: Skipping overlapping entity 'Lovely Public Sr. Sec. School' (College Name)
# Warning: Skipping overlapping entity 'Principal System Engineer' (Designation)
# Warning: Skipping overlapping entity 'Infosys' (Companies worked at)
# Warning: Skipping overlapping entity 'Infosys' (Companies worked at)
# Warning: Skipping overlapping entity 'indeed.com/r/Dilliraja-Baskaran/4a3bc8a35879ce5c' (Email Address)
# Warning: Skipping overlapping entity 'lecturer' (Designation)
# Warning: Skipping overlapping entity 'lecturer' (Designation)
# Warning: Skipping overlapping entity 'lecturer' (Designation)
# Warning: Skipping overlapping entity 'lecturer' (Designation)
# Warning: Skipping overlapping entity 'Mumbai' (Location)
# Warning: Skipping overlapping entity 'Mumbai' (Location)
# Warning: Skipping overlapping entity 'MCA' (Degree)
# Warning: Skipping overlapping entity 'Mumbai University' (College Name)
# Warning: Skipping overlapping entity 'Software Automation Engineer' (Designation)
# Warning: Skipping overlapping entity 'Pune,' (Location)
# Warning: Skipping overlapping entity 'Ulhasnagar' (Location)
# Warning: Skipping overlapping entity '2015' (Graduation Year)
# Warning: Skipping overlapping entity 'Automation developer' (Designation)
# Warning: Skipping overlapping entity 'indeed.com/r/Anvitha-Rao/9d6acc68cc30c71c' (Email Address)
# Warning: Skipping overlapping entity 'SAP Labs' (Companies worked at)
# Warning: Skipping overlapping entity 'Bengaluru' (Location)
# Warning: Skipping overlapping entity 'Bengaluru' (Location)
# Warning: Skipping overlapping entity '2016' (Graduation Year)
# Warning: Skipping overlapping entity '2016' (Graduation Year)
# Warning: Skipping overlapping entity '2016' (Graduation Year)
# Warning: Skipping overlapping entity 'Major Incident Manager / Escalation Manager' (Designation)
# Warning: Skipping overlapping entity 'Major Incident Manager / Escalation Manager' (Designation)
# Warning: Skipping overlapping entity 'Microsoft India' (Companies worked at)
# Warning: Skipping overlapping entity 'Osmania University' (College Name)
# Warning: Skipping overlapping entity 'Operational Analyst (SQL DBA) Engineer' (Designation)
# Warning: Skipping overlapping entity 'UNISYS' (Companies worked at)
# Warning: Skipping overlapping entity 'Bengaluru' (Location)
# Warning: Skipping overlapping entity 'Bengaluru' (Location)
# Warning: Skipping overlapping entity 'Bengaluru' (Location)
# Warning: Skipping overlapping entity 'indeed.com/r/Alok-Khandai/5be849e443b8f467' (Email Address)
# Warning: Skipping overlapping entity 'Financial Analyst' (Designation)
# Warning: Skipping overlapping entity 'Oracle' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle' (Companies worked at)
# Warning: Skipping overlapping entity 'Excel' (Skills)
# Warning: Skipping overlapping entity 'Excel' (Skills)
# Warning: Skipping overlapping entity 'Tally' (Skills)
# Warning: Skipping overlapping entity 'West Bengal State' (Degree)
# Warning: Skipping overlapping entity 'System Administrator (Server)' (Designation)
# Warning: Skipping overlapping entity 'System Administrator (Server)' (Designation)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Tiruchchirappalli' (Location)
# Warning: Skipping overlapping entity 'Tiruchchirappalli' (Location)
# Warning: Skipping overlapping entity 'Program Manager (Software Delivery)' (Designation)
# Warning: Skipping overlapping entity 'Office Beacon' (Companies worked at)
# Warning: Skipping overlapping entity 'Vadodara' (Location)
# Warning: Skipping overlapping entity 'Kerala State' (College Name)
# Warning: Skipping overlapping entity 'Trichur,' (Location)
# Warning: Skipping overlapping entity 'Trichur,' (Location)
# Warning: Skipping overlapping entity '2017' (Graduation Year)
# Warning: Skipping overlapping entity '2017' (Graduation Year)
# Warning: Skipping overlapping entity 'SAP ABAP' (Companies worked at)
# Warning: Skipping overlapping entity 'SAP ABAP' (Companies worked at)
# Warning: Skipping overlapping entity 'SAP ABAP' (Companies worked at)
# Warning: Skipping overlapping entity 'SAP ABAP' (Companies worked at)
# Warning: Skipping overlapping entity 'SAP ABAP' (Companies worked at)
# Warning: Skipping overlapping entity 'SAP ABAP' (Companies worked at)
# Warning: Skipping overlapping entity 'SAP ABAP' (Companies worked at)
# Warning: Skipping overlapping entity 'SAP ABAP' (Companies worked at)
# Warning: Skipping overlapping entity 'SAP ABAP' (Companies worked at)
# Warning: Skipping overlapping entity 'Consultant' (Designation)
# Warning: Skipping overlapping entity 'Consultant' (Designation)
# Warning: Skipping overlapping entity 'Consultant' (Designation)
# Warning: Skipping overlapping entity 'Consultant' (Designation)
# Warning: Skipping overlapping entity 'Consultant' (Designation)
# Warning: Skipping overlapping entity 'Consultant' (Designation)
# Warning: Skipping overlapping entity 'Consultant' (Designation)
# Warning: Skipping overlapping entity 'Consultant' (Designation)
# Warning: Skipping overlapping entity 'Hyderabad' (Location)
# Warning: Skipping overlapping entity 'Hyderabad' (Location)
# Warning: Skipping overlapping entity 'Hyderabad' (Location)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'I Phone solution Consultant' (Designation)
# Warning: Skipping overlapping entity 'SAP EWM' (Companies worked at)
# Warning: Skipping overlapping entity 'SAP EWM' (Companies worked at)
# Warning: Skipping overlapping entity 'SAP EWM' (Companies worked at)
# Warning: Skipping overlapping entity 'SAP EWM' (Companies worked at)
# Warning: Skipping overlapping entity 'SAP EWM' (Companies worked at)
# Warning: Skipping overlapping entity '2007' (Graduation Year)
# Warning: Skipping overlapping entity 'Anna University' (College Name)
# Warning: Skipping overlapping entity '2005' (Graduation Year)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Subject matter Expert' (Designation)
# Warning: Skipping overlapping entity 'Accenture' (Companies worked at)
# Warning: Skipping overlapping entity '2.5 years' (Years of Experience)
# Warning: Skipping overlapping entity '2.5 years' (Years of Experience)
# Warning: Skipping overlapping entity 'Oracle' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle Fusion Middleware' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle Fusion Middleware' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle Fusion Middleware' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle' (Skills)
# Warning: Skipping overlapping entity 'Oracle Fusion Middleware' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle Fusion Middleware' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle Fusion Middleware' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle Fusion Middleware' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle Fusion Middleware' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle' (Companies worked at)
# Warning: Skipping overlapping entity 'Technical Consultant' (Designation)
# Warning: Skipping overlapping entity 'Technical Consultant' (Designation)
# Warning: Skipping overlapping entity 'Technical Consultant' (Designation)
# Warning: Skipping overlapping entity 'Technical Consultant' (Designation)
# Warning: Skipping overlapping entity 'Technical Consultant' (Designation)
# Warning: Skipping overlapping entity 'Technical Consultant' (Designation)
# Warning: Skipping overlapping entity '2015' (Graduation Year)
# Warning: Skipping overlapping entity 'indeed.com/r/Jacob-Philip/db00d831146c9228' (Email Address)
# Warning: Skipping overlapping entity 'Team Lead' (Designation)
# Warning: Skipping overlapping entity 'Team Lead' (Designation)
# Warning: Skipping overlapping entity 'Team Lead' (Designation)
# Warning: Skipping overlapping entity 'Team Lead' (Designation)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'indeed.com/r/Ashok-Kunam/7aac8767aacf10a0' (Email Address)
# Warning: Skipping overlapping entity 'Team member' (Designation)
# Warning: Skipping overlapping entity 'Oracle' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle' (Companies worked at)
# Warning: Skipping overlapping entity 'Bangalore' (Location)
# Warning: Skipping overlapping entity 'Bangalore' (Location)
# Warning: Skipping overlapping entity 'Bangalore' (Location)
# Warning: Skipping overlapping entity 'Bangalore' (Location)
# Warning: Skipping overlapping entity 'Senior Systems Engineer' (Designation)
# Warning: Skipping overlapping entity 'Senior Systems Engineer' (Designation)
# Warning: Skipping overlapping entity 'Senior Systems Engineer' (Designation)
# Warning: Skipping overlapping entity 'Infosys Limited' (Companies worked at)
# Warning: Skipping overlapping entity 'Bengaluru' (Location)
# Warning: Skipping overlapping entity 'Bengaluru' (Location)
# Warning: Skipping overlapping entity 'Bengaluru' (Location)
# Warning: Skipping overlapping entity 'Store Executive' (Designation)
# Warning: Skipping overlapping entity 'Store Executive' (Designation)
# Warning: Skipping overlapping entity 'Orange City Hospital & Research Institute' (College Name)
# Warning: Skipping overlapping entity 'Nagpur' (Location)
# Warning: Skipping overlapping entity 'Nagpur' (Location)
# Warning: Skipping overlapping entity 'Software Development Director' (Designation)
# Warning: Skipping overlapping entity 'Software Development Director' (Designation)
# Warning: Skipping overlapping entity 'Oracle Inc' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle Inc' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle Inc' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle Inc' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle Inc' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle Inc' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle Inc' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle Inc' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle Inc' (Companies worked at)
# Warning: Skipping overlapping entity 'Senior Development Manager' (Designation)
# Warning: Skipping overlapping entity 'indeed.com/r/Gunjan-Nayyar/a5819ca6733a0f41' (Email Address)
# Warning: Skipping overlapping entity 'INFOSYS' (Companies worked at)
# Warning: Skipping overlapping entity 'Member of Discipline Committee in ALGORYTHM' (Designation)
# Warning: Skipping overlapping entity 'Associate' (Designation)
# Warning: Skipping overlapping entity 'Bengaluru' (Location)
# Warning: Skipping overlapping entity 'Puneet' (Location)
# Warning: Skipping overlapping entity 'Puneet Bhandari' (Name)
# Warning: Skipping overlapping entity 'Puneet' (Location)
# Warning: Skipping overlapping entity 'SAP SD lead' (Designation)
# Warning: Skipping overlapping entity 'SAP SD lead' (Designation)
# Warning: Skipping overlapping entity 'SAP SD lead' (Designation)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'indeed.com/r/Puneet-Bhandari/c9002fa44d6760bd' (Email Address)
# Warning: Skipping overlapping entity '2008' (Graduation Year)
# Warning: Skipping overlapping entity '2014' (Graduation Year)
# Warning: Skipping overlapping entity 'Bidar' (Location)
# Warning: Skipping overlapping entity 'Bidar' (Location)
# Warning: Skipping overlapping entity 'indeed.com/r/Ravi-Shivgond/4018c67548312089' (Email Address)
# Warning: Skipping overlapping entity 'Offshore SAP CRM Functional Consultant' (Designation)
# Warning: Skipping overlapping entity 'SAP Labs' (Companies worked at)
# Warning: Skipping overlapping entity 'SAP Labs' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft dynamics AX Technical consultant' (Designation)
# Warning: Skipping overlapping entity 'Microsoft dynamics AX Technical consultant' (Designation)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'dynamics AX Technical consultant' (Designation)
# Warning: Skipping overlapping entity 'dynamics AX Technical consultant' (Designation)
# Warning: Skipping overlapping entity 'Developer' (Designation)
# Warning: Skipping overlapping entity 'Developer' (Designation)
# Warning: Skipping overlapping entity 'Infosys Limited' (Companies worked at)
# Warning: Skipping overlapping entity 'Application Development Associate' (Designation)
# Warning: Skipping overlapping entity 'Accenture' (Companies worked at)
# Warning: Skipping overlapping entity 'Georgia Institute of Technology' (College Name)
# Warning: Skipping overlapping entity 'Senior Process Executive' (Designation)
# Warning: Skipping overlapping entity 'Bengaluru' (Location)
# Warning: Skipping overlapping entity 'Certified Network Associate Training Program' (Designation)
# Warning: Skipping overlapping entity 'Vijayalakshmi Govindarajan' (Name)
# Warning: Skipping overlapping entity 'SAP Basis' (Companies worked at)
# Warning: Skipping overlapping entity 'SAP Basis' (Companies worked at)
# Warning: Skipping overlapping entity 'SAP Basis' (Companies worked at)
# Warning: Skipping overlapping entity 'SAP Basis' (Companies worked at)
# Warning: Skipping overlapping entity 'SAP Basis' (Companies worked at)
# Warning: Skipping overlapping entity 'SAP Basis' (Companies worked at)
# Warning: Skipping overlapping entity 'SAP Basis' (Companies worked at)
# Warning: Skipping overlapping entity 'TVS Lakshmi Matriculation Higher Secondary School' (College Name)
# Warning: Skipping overlapping entity '2013' (Graduation Year)
# Warning: Skipping overlapping entity 'indeed.com/r/Avani-Priya/fe6b4c5516207abe' (Email Address)
# Warning: Skipping overlapping entity 'Software Test Automation Engineer' (Designation)
# Warning: Skipping overlapping entity 'Sr. Test Manager' (Designation)
# Warning: Skipping overlapping entity 'Mumbai' (Location)
# Warning: Skipping overlapping entity 'indeed.com/r/Srinivas-VO/39c80e42cb6bc97f' (Email Address)
# Warning: Skipping overlapping entity 'Senior Technology Support Executive' (Designation)
# Warning: Skipping overlapping entity 'Senior Technology Support Executive' (Designation)
# Warning: Skipping overlapping entity 'Infosys' (Companies worked at)
# Warning: Skipping overlapping entity 'Infosys' (Companies worked at)
# Warning: Skipping overlapping entity '2006' (Graduation Year)
# Warning: Skipping overlapping entity 'Infosys Limited' (Companies worked at)
# Warning: Skipping overlapping entity 'indeed.com/r/Kavitha-K/8977ce8ce48bc800' (Email Address)
# Warning: Skipping overlapping entity '2014' (Graduation Year)
# Warning: Skipping overlapping entity 'Hyderabad' (Location)
# Warning: Skipping overlapping entity 'NOC and QA Engineer' (Designation)
# Warning: Skipping overlapping entity 'Skava an Infosys Company' (Companies worked at)
# Warning: Skipping overlapping entity 'Coimbatore' (Location)
# Warning: Skipping overlapping entity 'Mumbai' (Location)
# Warning: Skipping overlapping entity 'indeed.com/r/Snehal-Jadhav/005e1ab800b4cb42' (Email Address)
# Warning: Skipping overlapping entity 'Cisco' (Companies worked at)
# Warning: Skipping overlapping entity 'Cisco' (Companies worked at)
# Warning: Skipping overlapping entity 'Cisco' (Companies worked at)
# Warning: Skipping overlapping entity 'Cisco' (Companies worked at)
# Warning: Skipping overlapping entity 'Cisco' (Companies worked at)
# Warning: Skipping overlapping entity 'Maharashtra Board' (College Name)
# Warning: Skipping overlapping entity 'Consultant' (Designation)
# Warning: Skipping overlapping entity 'Consultant' (Designation)
# Warning: Skipping overlapping entity 'SAP ABAP' (Companies worked at)
# Warning: Skipping overlapping entity 'SAP ABAP' (Companies worked at)
# Warning: Skipping overlapping entity '2010' (Graduation Year)
# Warning: Skipping overlapping entity 'Volunteer Contestant, Yappon' (Designation)
# Warning: Skipping overlapping entity 'Senior Technical Lead' (Designation)
# Warning: Skipping overlapping entity 'Technical Lead' (Designation)
# Warning: Skipping overlapping entity 'Technical Lead' (Designation)
# Warning: Skipping overlapping entity 'Technical Lead' (Designation)
# Warning: Skipping overlapping entity 'Technical Lead' (Designation)
# Warning: Skipping overlapping entity 'Technical Lead' (Designation)
# Warning: Skipping overlapping entity 'Cisco' (Companies worked at)
# Warning: Skipping overlapping entity 'Cisco' (Companies worked at)
# Warning: Skipping overlapping entity 'Cisco' (Companies worked at)
# Warning: Skipping overlapping entity 'Cisco' (Companies worked at)
# Warning: Skipping overlapping entity 'Cisco' (Companies worked at)
# Warning: Skipping overlapping entity 'Cisco' (Companies worked at)
# Warning: Skipping overlapping entity 'Cisco' (Companies worked at)
# Warning: Skipping overlapping entity 'Cisco' (Companies worked at)
# Warning: Skipping overlapping entity 'Cisco' (Companies worked at)
# Warning: Skipping overlapping entity 'Cisco' (Companies worked at)
# Warning: Skipping overlapping entity 'Cisco' (Companies worked at)
# Warning: Skipping overlapping entity 'Cisco' (Companies worked at)
# Warning: Skipping overlapping entity 'Cisco' (Companies worked at)
# Warning: Skipping overlapping entity 'Cisco' (Companies worked at)
# Warning: Skipping overlapping entity 'Cisco' (Companies worked at)
# Warning: Skipping overlapping entity 'Cisco' (Companies worked at)
# Warning: Skipping overlapping entity 'Cisco' (Companies worked at)
# Warning: Skipping overlapping entity 'Cisco' (Companies worked at)
# Warning: Skipping overlapping entity 'Cisco' (Companies worked at)
# Warning: Skipping overlapping entity 'Cisco' (Companies worked at)
# Warning: Skipping overlapping entity 'Cisco' (Companies worked at)
# Warning: Skipping overlapping entity 'Cisco' (Companies worked at)
# Warning: Skipping overlapping entity 'Cisco' (Companies worked at)
# Warning: Skipping overlapping entity 'indeed.com/r/Senthil-Kumar/d9d82865dd38d449' (Email Address)
# Warning: Skipping overlapping entity 'Chandigarh' (Location)
# Warning: Skipping overlapping entity 'Chandigarh' (Location)
# Warning: Skipping overlapping entity 'Chandigarh' (Location)
# Warning: Skipping overlapping entity 'Chandigarh' (Location)
# Warning: Skipping overlapping entity 'Chandigarh' (Location)
# Warning: Skipping overlapping entity '2013' (Graduation Year)
# Warning: Skipping overlapping entity '2013' (Graduation Year)
# Warning: Skipping overlapping entity '2013' (Graduation Year)
# Warning: Skipping overlapping entity 'Infosys Limited' (Companies worked at)
# Warning: Skipping overlapping entity 'Infosys Limited' (Companies worked at)
# Warning: Skipping overlapping entity 'Acharya Nagarjuna University' (College Name)
# Warning: Skipping overlapping entity 'Software Development Engineer' (Designation)
# Warning: Skipping overlapping entity '6 months' (Years of Experience)
# Warning: Skipping overlapping entity 'Java' (Skills)
# Warning: Skipping overlapping entity 'Java' (Skills)
# Warning: Skipping overlapping entity 'Java' (Skills)
# Warning: Skipping overlapping entity 'Java' (Skills)
# Warning: Skipping overlapping entity 'Java' (Skills)
# Warning: Skipping overlapping entity 'Java' (Skills)
# Warning: Skipping overlapping entity 'Java' (Skills)
# Warning: Skipping overlapping entity 'Java' (Skills)
# Warning: Skipping overlapping entity 'C' (Skills)
# Warning: Skipping overlapping entity 'C' (Skills)
# Warning: Skipping overlapping entity 'C' (Skills)
# Warning: Skipping overlapping entity 'C' (Skills)
# Warning: Skipping overlapping entity 'Velocity' (Skills)
# Warning: Skipping overlapping entity 'Velocity' (Skills)
# Warning: Skipping overlapping entity 'Velocity' (Skills)
# Warning: Skipping overlapping entity 'Velocity' (Skills)
# Warning: Skipping overlapping entity 'Web Development' (Skills)
# Warning: Skipping overlapping entity 'Amazon' (Companies worked at)
# Warning: Skipping overlapping entity 'Amazon' (Companies worked at)
# Warning: Skipping overlapping entity 'Amazon' (Companies worked at)
# Warning: Skipping overlapping entity 'Amazon' (Companies worked at)
# Warning: Skipping overlapping entity 'Amazon' (Companies worked at)
# Warning: Skipping overlapping entity 'Amazon' (Companies worked at)
# Warning: Skipping overlapping entity 'Amazon' (Companies worked at)
# Warning: Skipping overlapping entity 'Amazon' (Companies worked at)
# Warning: Skipping overlapping entity 'Amazon' (Companies worked at)
# Warning: Skipping overlapping entity 'Amazon' (Companies worked at)
# Warning: Skipping overlapping entity 'Amazon' (Companies worked at)
# Warning: Skipping overlapping entity 'Amazon' (Companies worked at)
# Warning: Skipping overlapping entity 'Amazon' (Companies worked at)
# Warning: Skipping overlapping entity 'Amazon' (Companies worked at)
# Warning: Skipping overlapping entity 'Amazon' (Companies worked at)
# Warning: Skipping overlapping entity 'Amazon Development Centre' (Companies worked at)
# Warning: Skipping overlapping entity 'Amazon' (Companies worked at)
# Warning: Skipping overlapping entity 'Amazon' (Companies worked at)
# Warning: Skipping overlapping entity 'Amazon Development Centre' (Companies worked at)
# Warning: Skipping overlapping entity 'Amazon' (Companies worked at)
# Warning: Skipping overlapping entity '2017' (Graduation Year)
# Warning: Skipping overlapping entity 'JSP' (Skills)
# Warning: Skipping overlapping entity 'HTML' (Skills)
# Warning: Skipping overlapping entity 'PHP' (Skills)
# Warning: Skipping overlapping entity 'SQL' (Skills)
# Warning: Skipping overlapping entity 'Online Content Writer' (Designation)
# Warning: Skipping overlapping entity 'Android' (Skills)
# Warning: Skipping overlapping entity 'Android' (Skills)
# Warning: Skipping overlapping entity 'Android' (Skills)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Pune' (Location)
# Warning: Skipping overlapping entity 'indeed.com/r/Raktim-Podder/32472fc557546084' (Email Address)
# Warning: Skipping overlapping entity 'SME' (Designation)
# Warning: Skipping overlapping entity 'Oceanic Consultants' (Designation)
# Warning: Skipping overlapping entity 'Oceanic Consultants' (Designation)
# Warning: Skipping overlapping entity 'Oceanic Consultants' (Companies worked at)
# Warning: Skipping overlapping entity 'HR Executive' (Companies worked at)
# Warning: Skipping overlapping entity 'Chief Coordinator of LEAR' (Designation)
# Warning: Skipping overlapping entity 'Chief Coordinator of LEAR' (Designation)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Pune' (Location)
# Warning: Skipping overlapping entity 'Pune' (Location)
# Warning: Skipping overlapping entity 'Pune' (Location)
# Warning: Skipping overlapping entity 'Pune' (Location)
# Warning: Skipping overlapping entity 'Pune' (Location)
# Warning: Skipping overlapping entity 'indeed.com/r/Ravi-Shankar/befa180dc0449299' (Email Address)
# Warning: Skipping overlapping entity 'B.E.' (Degree)
# Warning: Skipping overlapping entity 'SCOM' (Skills)
# Warning: Skipping overlapping entity 'SCOM' (Skills)
# Warning: Skipping overlapping entity 'SCOM' (Skills)
# Warning: Skipping overlapping entity 'OPERATIONS MANAGER' (Skills)
# Warning: Skipping overlapping entity 'Microsoft SQL-SERVER' (Designation)
# Warning: Skipping overlapping entity 'Microsoft SQL-SERVER' (Designation)
# Warning: Skipping overlapping entity 'Dhule' (Location)
# Warning: Skipping overlapping entity 'Dhule' (Location)
# Warning: Skipping overlapping entity 'indeed.com/r/Pankaj-Bhosale/2d6f2e970b9a7ff6' (Email Address)
# Warning: Skipping overlapping entity 'PMO' (Designation)
# Warning: Skipping overlapping entity 'PMO' (Designation)
# Warning: Skipping overlapping entity 'PMO' (Designation)
# Warning: Skipping overlapping entity 'PMO' (Designation)
# Warning: Skipping overlapping entity 'PMO' (Designation)
# Warning: Skipping overlapping entity 'Bengaluru' (Location)
# Warning: Skipping overlapping entity 'Bengaluru' (Location)
# Warning: Skipping overlapping entity 'Bengaluru' (Location)
# Warning: Skipping overlapping entity 'Bengaluru' (Location)
# Warning: Skipping overlapping entity 'Bengaluru' (Location)
# Warning: Skipping overlapping entity 'Bengaluru' (Location)
# Warning: Skipping overlapping entity 'Bengaluru' (Location)
# Warning: Skipping overlapping entity 'Infosys BPO Ltd' (Companies worked at)
# Warning: Skipping overlapping entity 'Infosys BPO Ltd' (Companies worked at)
# Warning: Skipping overlapping entity 'Infosys BPO Ltd' (Companies worked at)
# Warning: Skipping overlapping entity 'Infosys BPO Ltd' (Companies worked at)
# Warning: Skipping overlapping entity 'Infosys BPO Ltd' (Companies worked at)
# Warning: Skipping overlapping entity 'Infosys BPO Ltd' (Companies worked at)
# Warning: Skipping overlapping entity 'Infosys BPO Ltd' (Companies worked at)
# Warning: Skipping overlapping entity '2004' (Years of Experience)
# Warning: Skipping overlapping entity 'Test Engineer' (Designation)
# Warning: Skipping overlapping entity 'Test Engineer' (Designation)
# Warning: Skipping overlapping entity 'Mangalore' (Location)
# Warning: Skipping overlapping entity 'Mangalore' (Location)
# Warning: Skipping overlapping entity 'Mangalore' (Location)
# Warning: Skipping overlapping entity 'Mangalore' (Location)
# Warning: Skipping overlapping entity 'Infosys' (Companies worked at)
# Warning: Skipping overlapping entity 'Infosys' (Companies worked at)
# Warning: Skipping overlapping entity '2014' (Graduation Year)
# Warning: Skipping overlapping entity '2014' (Graduation Year)
# Warning: Skipping overlapping entity 'Hyderabad,' (Location)
# Warning: Skipping overlapping entity 'Hyderabad,' (Location)
# Warning: Skipping overlapping entity 'indeed.com/r/Sanand-Pal/5c99c42c3400737c' (Email Address)
# Warning: Skipping overlapping entity 'Lead Engineer' (Designation)
# Warning: Skipping overlapping entity 'Lead Engineer' (Designation)
# Warning: Skipping overlapping entity 'Automation & Testing' (Companies worked at)
# Warning: Skipping overlapping entity 'Automation & Testing' (Companies worked at)
# Warning: Skipping overlapping entity 'Automation & Testing' (Companies worked at)
# Warning: Skipping overlapping entity 'Automation & Testing' (Companies worked at)
# Warning: Skipping overlapping entity 'Automation & Testing' (Companies worked at)
# Warning: Skipping overlapping entity '4 years' (Years of Experience)
# Warning: Skipping overlapping entity '4 years' (Years of Experience)
# Warning: Skipping overlapping entity '4 years' (Years of Experience)
# Warning: Skipping overlapping entity '4 years' (Years of Experience)
# Warning: Skipping overlapping entity 'Cisco Systems' (Companies worked at)
# Warning: Skipping overlapping entity 'Cisco Systems' (Companies worked at)
# Warning: Skipping overlapping entity 'Cisco Systems' (Companies worked at)
# Warning: Skipping overlapping entity '2011' (Graduation Year)
# Warning: Skipping overlapping entity 'Cloud Engineer' (Designation)
# Warning: Skipping overlapping entity '-Oracle' (Companies worked at)
# Warning: Skipping overlapping entity '-Oracle' (Companies worked at)
# Warning: Skipping overlapping entity '-Oracle' (Companies worked at)
# Warning: Skipping overlapping entity '-Oracle' (Companies worked at)
# Warning: Skipping overlapping entity '-Oracle' (Companies worked at)
# Warning: Skipping overlapping entity '-Oracle' (Companies worked at)
# Warning: Skipping overlapping entity '-Oracle' (Companies worked at)
# Warning: Skipping overlapping entity '-Oracle' (Companies worked at)
# Warning: Skipping overlapping entity '-Oracle' (Companies worked at)
# Warning: Skipping overlapping entity '-Oracle' (Companies worked at)
# Warning: Skipping overlapping entity '-Oracle' (Companies worked at)
# Warning: Skipping overlapping entity 'Hyderabad' (Location)
# Warning: Skipping overlapping entity 'Hyderabad' (Location)
# Warning: Skipping overlapping entity 'Hyderabad' (Location)
# Warning: Skipping overlapping entity 'Hyderabad' (Location)
# Warning: Skipping overlapping entity 'Hyderabad' (Location)
# Warning: Skipping overlapping entity 'Hyderabad' (Location)
# Warning: Skipping overlapping entity 'AWS' (Skills)
# Warning: Skipping overlapping entity 'AWS' (Skills)
# Warning: Skipping overlapping entity 'AWS' (Skills)
# Warning: Skipping overlapping entity 'AWS' (Skills)
# Warning: Skipping overlapping entity 'AWS' (Skills)
# Warning: Skipping overlapping entity 'AWS' (Skills)
# Warning: Skipping overlapping entity 'AWS' (Skills)
# Warning: Skipping overlapping entity 'AWS' (Skills)
# Warning: Skipping overlapping entity 'AWS' (Skills)
# Warning: Skipping overlapping entity 'AWS' (Skills)
# Warning: Skipping overlapping entity 'CHEF' (Skills)
# Warning: Skipping overlapping entity 'CHEF' (Skills)
# Warning: Skipping overlapping entity 'CHEF' (Skills)
# Warning: Skipping overlapping entity 'CHEF' (Skills)
# Warning: Skipping overlapping entity 'CHEF' (Skills)
# Warning: Skipping overlapping entity 'CHEF' (Skills)
# Warning: Skipping overlapping entity 'Docker' (Skills)
# Warning: Skipping overlapping entity 'Docker' (Skills)
# Warning: Skipping overlapping entity 'Docker' (Skills)
# Warning: Skipping overlapping entity 'Docker' (Skills)
# Warning: Skipping overlapping entity 'Docker' (Skills)
# Warning: Skipping overlapping entity 'Configuration Engineer' (Designation)
# Warning: Skipping overlapping entity 'Configuration Engineer' (Designation)
# Warning: Skipping overlapping entity 'Configuration Engineer' (Designation)
# Warning: Skipping overlapping entity '2015' (Graduation Year)
# Warning: Skipping overlapping entity 'Annamacharya Institute of Technology' (College Name)
# Warning: Skipping overlapping entity 'Linux' (Skills)
# Warning: Skipping overlapping entity 'Linux' (Skills)
# Warning: Skipping overlapping entity 'Linux' (Skills)
# Warning: Skipping overlapping entity 'Linux' (Skills)
# Warning: Skipping overlapping entity 'Linux' (Skills)
# Warning: Skipping overlapping entity 'Linux' (Skills)
# Warning: Skipping overlapping entity 'Linux' (Skills)
# Warning: Skipping overlapping entity 'Linux' (Skills)
# Warning: Skipping overlapping entity 'Hyderabad' (Location)
# Warning: Skipping overlapping entity 'Hyderabad' (Location)
# Warning: Skipping overlapping entity 'Hyderabad' (Location)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Tech Support Executive' (Designation)
# Warning: Skipping overlapping entity 'Tech Support Executive' (Designation)
# Warning: Skipping overlapping entity 'Teleperformance for Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'indeed.com/r/Nida-Khan/6c9160696f57efd8' (Email Address)
# Warning: Skipping overlapping entity 'Senior System Engineer at Infosys Limited' (Designation)
# Warning: Skipping overlapping entity 'Senior System Engineer at Infosys Limited' (Designation)
# Warning: Skipping overlapping entity 'Infosys' (Companies worked at)
# Warning: Skipping overlapping entity 'Infosys' (Companies worked at)
# Warning: Skipping overlapping entity 'Infosys' (Companies worked at)
# Warning: Skipping overlapping entity 'Infosys' (Companies worked at)
# Warning: Skipping overlapping entity 'Akansha Jain' (Name)
# Warning: Skipping overlapping entity 'Pune,' (Location)
# Warning: Skipping overlapping entity 'Developer' (Designation)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity '2016' (Graduation Year)
# Warning: Skipping overlapping entity 'Pune' (Location)
# Warning: Skipping overlapping entity '2016' (Graduation Year)
# Warning: Skipping overlapping entity '2016' (Graduation Year)
# Warning: Skipping overlapping entity '2016' (Graduation Year)
# Warning: Skipping overlapping entity 'Senior Corporate Account Executive' (Designation)
# Warning: Skipping overlapping entity 'Senior Corporate Account Executive' (Designation)
# Warning: Skipping overlapping entity 'MongoDB' (Companies worked at)
# Warning: Skipping overlapping entity 'Gurgaon' (Location)
# Warning: Skipping overlapping entity 'indeed.com/r/Urshila-Lohani/ab8d3dc6dd8b13f0' (Email Address)
# Warning: Skipping overlapping entity 'Account Manager' (Designation)
# Warning: Skipping overlapping entity 'Oracle' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle' (Companies worked at)
# Warning: Skipping overlapping entity '2011' (Graduation Year)
# Warning: Skipping overlapping entity 'Senior Travel Operations' (Designation)
# Warning: Skipping overlapping entity 'International Travel House Limited' (Companies worked at)
# Warning: Skipping overlapping entity 'International Travel House Limited' (Companies worked at)
# Warning: Skipping overlapping entity 'Visakhapatnam' (Location)
# Warning: Skipping overlapping entity 'Visakhapatnam' (Location)
# Warning: Skipping overlapping entity 'Jr. ASP.NET Developer' (Designation)
# Warning: Skipping overlapping entity 'Jr. ASP.NET Developer' (Designation)
# ...
# Warning: Skipping overlapping entity 'Pune' (Location)
# Warning: Skipping overlapping entity 'indeed.com/r/Nitin-Verma/b9e8520147f728d2' (Email Address)
# Warning: Skipping overlapping entity 'Pune' (Location)
# Warning: Skipping overlapping entity 'Pune' (Location)
# Warning: Skipping overlapping entity 'Pune' (Location)
# Warning: Skipping overlapping entity 'indeed.com/r/Angad-Waghmare/42aa9e8655a5f7a3' (Email Address)
# Warning: Skipping overlapping entity 'Senior project engineer' (Designation)
# Warning: Skipping overlapping entity 'Senior project engineer' (Designation)
# Warning: Skipping overlapping entity 'Wipro' (Companies worked at)
# Warning: Skipping overlapping entity 'Wipro' (Companies worked at)
# Warning: Skipping overlapping entity 'Cisco' (Companies worked at)
# Warning: Skipping overlapping entity 'Cisco' (Companies worked at)
# Warning: Skipping overlapping entity 'Cisco' (Companies worked at)
# Warning: Skipping overlapping entity 'indeed.com/r/Afreen-Jamadar/8baf379b705e37c6' (Email Address)
# Warning: Skipping overlapping entity '13 years' (Years of Experience)
# Warning: Skipping overlapping entity 'Infosys Limited' (Companies worked at)
# Warning: Skipping overlapping entity 'Infosys Limited' (Companies worked at)
# Warning: Skipping overlapping entity 'Infosys Limited' (Companies worked at)
# Warning: Skipping overlapping entity 'Chennai' (Location)
# Warning: Skipping overlapping entity 'Chennai' (Location)
# Warning: Skipping overlapping entity 'Project Manager / Technology Lead' (Designation)
# Warning: Skipping overlapping entity 'Patna' (Location)
# Warning: Skipping overlapping entity 'Patna' (Location)
# Warning: Skipping overlapping entity 'indeed.com/r/Krishna-Prasad/b8d7a1135a44a37a' (Email Address)
# Warning: Skipping overlapping entity 'Technical Architect' (Designation)
# Warning: Skipping overlapping entity 'Technical Architect' (Designation)
# Warning: Skipping overlapping entity 'Technical Architect' (Designation)
# Warning: Skipping overlapping entity 'Technical Architect' (Designation)
# Warning: Skipping overlapping entity 'Technical Architect' (Designation)
# Warning: Skipping overlapping entity 'Technical Architect & Sr. Software Engineer' (Designation)
# Warning: Skipping overlapping entity 'Technical Architect' (Designation)
# Warning: Skipping overlapping entity 'Pune' (Location)
# Warning: Skipping overlapping entity 'indeed.com/r/Girish-Acharya/6757f94ee9f4ec23' (Email Address)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Officer-HR & Administration in H.& R. Johnson (India)' (Designation)
# Warning: Skipping overlapping entity 'Officer-HR & Administration in H.& R. Johnson (India)' (Designation)
# Warning: Skipping overlapping entity 'SAP' (Companies worked at)
# Warning: Skipping overlapping entity 'SAP' (Companies worked at)
# Warning: Skipping overlapping entity 'SAP' (Companies worked at)
# Warning: Skipping overlapping entity 'SAP' (Companies worked at)
# Warning: Skipping overlapping entity 'SAP' (Companies worked at)
# Warning: Skipping overlapping entity 'SAP' (Companies worked at)
# Warning: Skipping overlapping entity 'SAP' (Companies worked at)
# Warning: Skipping overlapping entity 'SAP' (Companies worked at)
# Warning: Skipping overlapping entity 'SAP' (Companies worked at)
# Warning: Skipping overlapping entity 'SAP' (Companies worked at)
# Warning: Skipping overlapping entity 'SAP' (Companies worked at)
# Warning: Skipping overlapping entity 'Dewas' (Location)
# Warning: Skipping overlapping entity '2016' (Graduation Year)
# Warning: Skipping overlapping entity 'MICROSOFT' (Companies worked at)
# Warning: Skipping overlapping entity 'Backup Administrator' (Designation)
# Warning: Skipping overlapping entity 'Backup Administrator' (Designation)
# Warning: Skipping overlapping entity 'Backup Administrator' (Designation)
# Warning: Skipping overlapping entity 'Backup Administrator' (Designation)
# Warning: Skipping overlapping entity 'Backup Administrator' (Designation)
# Warning: Skipping overlapping entity 'Global Production Support Lead' (Designation)
# Warning: Skipping overlapping entity 'Global Production Support Lead' (Designation)
# Warning: Skipping overlapping entity 'Infosys Ltd' (Companies worked at)
# Warning: Skipping overlapping entity 'Pune' (Location)
# Warning: Skipping overlapping entity 'Pune' (Location)
# Warning: Skipping overlapping entity 'Pune' (Location)
# Warning: Skipping overlapping entity 'Quality Analyst' (Designation)
# Warning: Skipping overlapping entity 'Quality Analyst' (Designation)
# Warning: Skipping overlapping entity 'Quality Analyst' (Designation)
# Warning: Skipping overlapping entity 'ThoughtWorks Technologies' (Companies worked at)
# Warning: Skipping overlapping entity 'ThoughtWorks Technologies' (Companies worked at)
# Warning: Skipping overlapping entity 'ThoughtWorks Technologies' (Companies worked at)
# Warning: Skipping overlapping entity 'indeed.com/r/Arpit-Jain/3714fe32f98b03a9' (Email Address)
# Warning: Skipping overlapping entity 'M.Tech. in IT' (Degree)
# Warning: Skipping overlapping entity 'Bengaluru' (Location)
# Warning: Skipping overlapping entity 'Bengaluru' (Location)
# Warning: Skipping overlapping entity 'Bengaluru' (Location)
# Warning: Skipping overlapping entity 'Aggrigator' (Companies worked at)
# Warning: Skipping overlapping entity 'Cisco' (Companies worked at)
# Warning: Skipping overlapping entity 'Cisco' (Companies worked at)
# Warning: Skipping overlapping entity '2012' (Graduation Year)
# Warning: Skipping overlapping entity '2012' (Graduation Year)
# Warning: Skipping overlapping entity '2012' (Graduation Year)
# Warning: Skipping overlapping entity 'Software developer' (Designation)
# Warning: Skipping overlapping entity 'Microsoft Office Suite - Expert' (Designation)
# Warning: Skipping overlapping entity 'indeed.com/r/Vishwanath-P/06a16ac2d087d3c9' (Email Address)
# Warning: Skipping overlapping entity 'BSc' (Degree)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Software Engineer' (Designation)
# Warning: Skipping overlapping entity 'Software Engineer' (Designation)
# Warning: Skipping overlapping entity 'Principal Consultant' (Designation)
# Warning: Skipping overlapping entity 'Principal Consultant' (Designation)
# Warning: Skipping overlapping entity 'Principal Consultant' (Designation)
# Warning: Skipping overlapping entity 'Oracle' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle' (Companies worked at)
# Warning: Skipping overlapping entity 'Visvesvaraya Technological University' (College Name)
# Warning: Skipping overlapping entity 'Associate Consultant' (Designation)
# Warning: Skipping overlapping entity 'Associate Consultant' (Designation)
# Warning: Skipping overlapping entity 'Associate Consultant' (Designation)
# Warning: Skipping overlapping entity 'State Street' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle Corporation' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle Corporation' (Companies worked at)
# Warning: Skipping overlapping entity 'Oracle Corporation' (Companies worked at)
# Warning: Skipping overlapping entity '2011' (Graduation Year)
# Warning: Skipping overlapping entity 'QA Tester' (Designation)
# Warning: Skipping overlapping entity 'QA Tester' (Designation)
# Warning: Skipping overlapping entity 'Chennai' (Location)
# Warning: Skipping overlapping entity 'Viny Khandelwal' (Name)
# Warning: Skipping overlapping entity 'SELF EMPLOYED' (Designation)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft Student partner' (Designation)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Microsoft Student partner' (Designation)
# Warning: Skipping overlapping entity 'Microsoft' (Companies worked at)
# Warning: Skipping overlapping entity 'Data Analyst Intern' (Designation)
# Warning: Skipping overlapping entity 'Bengaluru' (Location)
# Warning: Skipping overlapping entity 'indeed.com/r/Hartej-Kathuria/04181c5962a4af19' (Email Address)
# Warning: Skipping overlapping entity 'Manipal University' (College Name)
# Warning: Skipping overlapping entity 'pradeep chauhan' (Name)
# Warning: Skipping overlapping entity 'Noida' (Location)
# Warning: Skipping overlapping entity 'Noida' (Location)
# Warning: Skipping overlapping entity 'Noida' (Location)
# Warning: Skipping overlapping entity 'Microsoft Azure (Basic Management)' (Designation)
# Warning: Skipping overlapping entity 'Microsoft Azure (Basic Management)' (Designation)
# Warning: Skipping overlapping entity 'Delhi' (Location)
# Warning: Skipping overlapping entity 'Delhi' (Location)
# Warning: Skipping overlapping entity 'Delhi' (Location)
# Warning: Skipping overlapping entity 'Delhi' (Location)
# Warning: Skipping overlapping entity 'Delhi' (Location)
# Warning: Skipping overlapping entity 'Delhi' (Location)
# Warning: Skipping overlapping entity 'Test Engineer' (Designation)
# Warning: Skipping overlapping entity 'Infosys Ltd' (Companies worked at)
# Warning: Skipping overlapping entity 'Chennai' (Location)
# Warning: Skipping overlapping entity '2013' (Graduation Year)
# Warning: Skipping overlapping entity 'FI/CO Consultant in Tech Mahindra' (Designation)
# Warning: Skipping overlapping entity 'SAP FICO' (Companies worked at)
# Warning: Skipping overlapping entity 'SAP FICO' (Companies worked at)
# Warning: Skipping overlapping entity 'SAP FICO' (Companies worked at)
# Warning: Skipping overlapping entity 'SAP FICO' (Companies worked at)
# Warning: Skipping overlapping entity 'SAP FICO' (Companies worked at)
# Warning: Skipping overlapping entity 'Thane' (Location)
# Warning: Skipping overlapping entity '2016' (Graduation Year)
# Warning: Skipping overlapping entity '2016' (Graduation Year)
# Warning: Skipping overlapping entity 'Cisco' (Companies worked at)
# Warning: Skipping overlapping entity 'Cisco' (Companies worked at)
# Warning: Skipping overlapping entity 'Cisco' (Companies worked at)
# Warning: Skipping overlapping entity 'Cisco' (Companies worked at)
# Warning: Skipping overlapping entity 'Cisco' (Companies worked at)
# Warning: Skipping overlapping entity 'Aptech Institute of Technology' (College Name)
# Warning: Skipping overlapping entity 'CES ASSOCIATE CONSULTANT' (Designation)
# Warning: Skipping overlapping entity 'indeed.com/r/Ramesh-HP/95fc615713630c4e' (Email Address)
# Warning: Skipping overlapping entity 'Mule ESB Integration Developer' (Designation)
# Warning: Skipping overlapping entity 'Cisco Systems' (Companies worked at)
# Warning: Skipping overlapping entity 'Cisco Systems' (Companies worked at)
# Warning: Skipping overlapping entity 'Cisco Systems' (Companies worked at)
# Warning: Skipping overlapping entity 'Cisco Systems' (Companies worked at)
# Warning: Skipping overlapping entity 'Cisco Systems' (Companies worked at)
# Warning: Skipping overlapping entity 'Cisco Systems' (Companies worked at)
# Warning: Skipping overlapping entity 'Software Engineer' (Designation)
# Warning: Skipping overlapping entity 'Software Engineer' (Designation)
# Warning: Skipping overlapping entity '2011' (Graduation Year)
# Warning: Skipping overlapping entity 'Senior Process Executive' (Designation)
# Warning: Skipping overlapping entity 'indeed.com/r/Arpit-Godha/4c363189fbff3de8' (Email Address)
# Warning: Skipping overlapping entity 'Senior Program coordinator' (Designation)
# Warning: Skipping overlapping entity 'oracle India Limited' (Companies worked at)
# Warning: Skipping overlapping entity 'oracle' (Companies worked at)
# Warning: Skipping overlapping entity 'indeed.com/r/arjun-ks/8e9247624a5095b4' (Email Address)
# Warning: Skipping overlapping entity 'Infosys' (Companies worked at)
# Warning: Skipping overlapping entity 'Infosys' (Companies worked at)
# Warning: Skipping overlapping entity 'Infosys' (Companies worked at)
# Warning: Skipping overlapping entity 'Infosys' (Companies worked at)
# Warning: Skipping overlapping entity '2014' (Graduation Year)
# Warning: Skipping overlapping entity 'Systems Engineer' (Designation)
# Warning: Skipping overlapping entity 'Infosys Limited' (Companies worked at)
# Warning: Skipping overlapping entity 'Infosys Limited' (Companies worked at)
# Warning: Skipping overlapping entity 'Infosys Limited' (Companies worked at)
# Warning: Skipping overlapping entity 'Rajapalaiyam' (Location)
# Warning: Skipping overlapping entity 'Escalation Specialist' (Designation)

# %%
import spacy
from spacy.training import Example

def train_spacy():
    nlp = spacy.blank('en')
    
    if 'ner' not in nlp.pipe_names:
        ner = nlp.add_pipe('ner', last=True)
    
    for _, annotations in train_data:
         for ent in annotations.get("entities"):
            ner.add_label(ent[2])
    
    other_pipes = [pipe for pipe in nlp.pipe_names if pipe != 'ner']
    with nlp.disable_pipes(*other_pipes):
        optimizer = nlp.initialize()
        
        for itn in range(10):
            print("Starting iteration " + str(itn))
            random.shuffle(train_data)
            losses = {}
            
            for text, annotations in train_data:
                doc = nlp.make_doc(text)
                example = Example.from_dict(doc, annotations)
                
                nlp.update(
                    [example],
                    drop=0.2,
                    sgd=optimizer,
                    losses=losses
                )
            print(losses)
    return nlp

# %%
nlp = train_spacy()
# Out:
# Starting iteration 0
# {'ner': np.float32(12204.455)}
# Starting iteration 1
# {'ner': np.float32(3686.8716)}
# Starting iteration 2
# {'ner': np.float32(2579.921)}
# Starting iteration 3
# {'ner': np.float32(2505.3833)}
# Starting iteration 4
# {'ner': np.float32(1832.9576)}
# Starting iteration 5
# {'ner': np.float32(1684.4795)}
# Starting iteration 6
# {'ner': np.float32(1543.4381)}
# Starting iteration 7
# {'ner': np.float32(1472.4783)}
# Starting iteration 8
# {'ner': np.float32(1449.6616)}
# Starting iteration 9
# {'ner': np.float32(1326.3341)}

# %%
import spacy
from itertools import chain
from sklearn.metrics import accuracy_score

def calculate_ner_accuracy(nlp, test_data):
    all_true_labels = []
    all_pred_labels = []
    
    for text, annotations in test_data:
        doc = nlp.make_doc(text)
        true_entities = annotations.get("entities", [])
        
        true_labels = ['O'] * len(doc)
        for start, end, label in true_entities:
            entity_text = text[start:end]
            
            entity_tokens = []
            for token in doc:
                if token.idx >= start and token.idx + len(token.text) <= end:
                    entity_tokens.append(token)
            
            if entity_tokens:
                for i, token in enumerate(entity_tokens):
                    if len(entity_tokens) == 1:
                        true_labels[token.i] = f'U-{label}' 
                    elif i == 0:
                        true_labels[token.i] = f'B-{label}'
                    elif i == len(entity_tokens) - 1:
                        true_labels[token.i] = f'L-{label}'
                    else:
                        true_labels[token.i] = f'I-{label}' 
        
        pred_doc = nlp(text)
        pred_labels = [token.ent_iob_ + ('-' + token.ent_type_ if token.ent_type_ else '') 
                      for token in pred_doc]
        
        pred_labels = [label.replace('B-', 'B-').replace('I-', 'I-').replace('O', 'O') 
                      for label in pred_labels]
        
        min_len = min(len(true_labels), len(pred_labels))
        all_true_labels.extend(true_labels[:min_len])
        all_pred_labels.extend(pred_labels[:min_len])
    
    accuracy = accuracy_score(all_true_labels, all_pred_labels)
    return accuracy

# %%
accuracy = calculate_ner_accuracy(nlp, test_data)
print(f"SPACY Accuracy: {accuracy:.4f}")
# Out:
# SPACY Accuracy: 0.9637
